# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\User\Downloads\sport_athletes.csv')
df
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %%
# df.groupby('Sport Type')[['Weight(kg)', 'Height(cm)', 'Wins']].max().rename(
#      columns={'Weight(kg)': 'max_weight' , 'Height(cm)': 'max_height', 'Wins': 'max_wins'})
# df.groupby('Sport Type')['Weight(kg)'].min().sort_values()
# df.groupby('Sport Type')['Height(cm)'].nlargest(2)

# %%
# df.groupby(['Country', 'Sport Type']).max()
# df.groupby(['Country', 'Sport Type']).max().loc[('USA', 'Basketball')]
# df.groupby(['Country', 'Sport Type']).max().xs(level='Sport Type', key='Soccer')
# לחלופין יכולתי פשוט להחליף את הסדר של הgroupby ולהשתמש בloc
# df[df['Sport Type'].isin(['Soccer', 'Tennis'])].groupby(['Country', 'Sport Type']).max().swaplevel()
df.agg({'Wins':['max', 'min', 'mean', 'std'], 'Height(cm)': ['max', 'min', 'mean', 'std']})
# Out:
#           Wins  Height(cm)
# max   6.000000  216.000000
# min   1.000000  142.000000
# mean  3.388889  181.333333
# std   1.102666   16.568473

# %%
new_rows = pd.DataFrame({ 'Country': ['Canada', 'USA'], 'Sport Type': ['Hockey', 'Skiing'],
'Athlete Name': ['Wayne Gretzky', 'Lindsey Vonn'], 'Height(cm)': [183, 172],
'Weight(kg)': [84, 68], 'Wins': [3, 4], 'Olympic Date': ['01/02/2002', '12/02/2010'] })

pd.concat([df, new_rows], axis=0, ignore_index=True)
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %%
# df['Olympic Date'] = pd.to_datetime(df['Olympic Date'], format='%d/%m/%Y')
# df.set_index('Olympic Date', inplace=True)
yearly_wins = df.resample(rule='YE')['Wins'].sum()
yearly_wins
yearly_wins[yearly_wins > 0]
# Out:
# Olympic Date
# 1970-12-31     3
# 1976-12-31     5
# 1980-12-31     5
# 1984-12-31     4
# 1988-12-31     4
# 1992-12-31     3
# 1998-12-31     3
# 2000-12-31     5
# 2004-12-31     8
# 2008-12-31    13
# 2012-12-31    26
# 2016-12-31    30
# 2020-12-31    13
# Name: Wins, dtype: int64

# %%
smoker = pd.read_csv(r'C:\Users\User\Downloads\athletes_smoking.csv')
smoker
# Out:
#          Athlete Name Smoking
# 0      Michael Jordan      No
# 1        LeBron James      No
# 2         Kobe Bryant     Yes
# 3          Usain Bolt      No
# 4        Simone Biles      No
# 5       Wayne Gretzky     Yes
# 6        Lindsey Vonn      No
# 7        Rafael Nadal      No
# 8        Lionel Messi     Yes
# 9   Cristiano Ronaldo      No
# 10      Megan Rapinoe      No
# 11       Kevin Durant      No
# 12   Shaquille O'Neal      No
# 13         Carl Lewis     Yes
# 14         Ian Thorpe      No

# %%
pd.merge(smoker, df, on='Athlete Name', how='inner') # או left
pd.merge(smoker, df, on='Athlete Name', how='outer') # או right
# Out:
#             Athlete Name Smoking      Country       Sport Type  Height(cm)  \
# 0         Michael Jordan      No          USA       Basketball         198
# 1           LeBron James      No          USA       Basketball         206
# 2            Kobe Bryant     Yes          USA       Basketball         198
# 3           Kevin Durant      No          USA       Basketball         208
# 4       Shaquille O'Neal      No          USA       Basketball         216
# 5                   Pelé     NaN       Brazil           Soccer         174
# 6                  Marta     NaN       Brazil           Soccer         163
# 7      Cristiano Ronaldo      No     Portugal           Soccer         187
# 8           Lionel Messi     Yes    Argentina           Soccer         170
# 9        Zinedine Zidane     NaN       France           Soccer         185
# 10         Megan Rapinoe      No          USA           Soccer         168
# ...
